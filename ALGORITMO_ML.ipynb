# %% [markdown]
# <a href="https://colab.research.google.com/github/alberths-mx/pruebas-ML/blob/main/ALGORITMO_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Regresión logística**
#
# Data set obtenido en formato .csv a través del portal de datos abiertos del Gobierno de México desde línea de comando de Google Colab para convertirlo en un dataframe mediante la conexión de Google Drive.
#
# El siguiente documento se modifico del original para convertir variables cuantitativas a variables cuantitativas, ya que, los algoritmos no permiten el análisis con información de tipo string.
#
# **Acceso al Banco de Datos:**
#
# https://datos.gob.mx/busca/dataset/donaciones-de-organos-y-tejidos-con-fines-de-trasplante-trimestral

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

dataset = pd.read_excel('/content/gdrive/MyDrive/4TO SEMESTRE LCDA/Trasplantes3erTrimestre2023_2.xlsx')

# %%
transplantes=dataset

# %%
print(transplantes.keys())
# Out:
# Index(['SEXO', 'EDAD AL TRANSPLANTE', 'CODIGO ENTIDAD FEDERATIVA TRASPLANTE',
#        'CODIGO ENTIDAD FEDERATIVA ORGANO', 'CODIGO ENTIDAD FEDERATIVA ORIGEN',
#        'ORGANO', 'TIPO TRASPLANTE'],
#       dtype='object')

# %%
print(transplantes.describe)
# Out:
# <bound method NDFrame.describe of       SEXO  EDAD AL TRANSPLANTE  CODIGO ENTIDAD FEDERATIVA TRASPLANTE  \
# 0        1                   32                                    21
# 1        2                   32                                    14
# 2        1                   32                                    14
# 3        1                   33                                    14
# 4        1                   35                                    14
# ...    ...                  ...                                   ...
# 1727     1                   49                                    15
# 1728     1                   20                                    15
# 1729     1                   73                                     9
# 1730     2                   70                                     9
# 1731     2                   61                                    15
#
#       CODIGO ENTIDAD FEDERATIVA ORGANO  CODIGO ENTIDAD FEDERATIVA ORIGEN  \
# ...

# %%
import numpy as np

# %%
dataset.head()
# Out:
#    SEXO  EDAD AL TRANSPLANTE  CODIGO ENTIDAD FEDERATIVA TRASPLANTE  \
# 0     1                   32                                    21
# 1     2                   32                                    14
# 2     1                   32                                    14
# 3     1                   33                                    14
# 4     1                   35                                    14
#
#    CODIGO ENTIDAD FEDERATIVA ORGANO  CODIGO ENTIDAD FEDERATIVA ORIGEN  ORGANO  \
# 0                                21                                21    1005
# 1                                14                                14    1005
# 2                                 6                                14    1005
# 3                                14                                14    1005
# 4                                14                                14    1005
#
#    TIPO TRASPLANTE
# 0                0
# 1                0
# 2                0
# ...

# %%
dataset[['SEXO','CODIGO ENTIDAD FEDERATIVA TRASPLANTE', 'CODIGO ENTIDAD FEDERATIVA ORIGEN', 'CODIGO ENTIDAD FEDERATIVA ORGANO', 'ORGANO']]
# Out:
#       SEXO  CODIGO ENTIDAD FEDERATIVA TRASPLANTE  \
# 0        1                                    21
# 1        2                                    14
# 2        1                                    14
# 3        1                                    14
# 4        1                                    14
# ...    ...                                   ...
# 1727     1                                    15
# 1728     1                                    15
# 1729     1                                     9
# 1730     2                                     9
# 1731     2                                    15
#
#       CODIGO ENTIDAD FEDERATIVA ORIGEN  CODIGO ENTIDAD FEDERATIVA ORGANO  \
# 0                                   21                                21
# 1                                   14                                14
# 2                                   14                                 6
# 3                                   14                                14
# ...

# %%
hombres = dataset[dataset['SEXO'] == 1]
hombres.head()
# Out:
#    SEXO  EDAD AL TRANSPLANTE  CODIGO ENTIDAD FEDERATIVA TRASPLANTE  \
# 0     1                   32                                    21
# 2     1                   32                                    14
# 3     1                   33                                    14
# 4     1                   35                                    14
# 6     1                   30                                    14
#
#    CODIGO ENTIDAD FEDERATIVA ORGANO  CODIGO ENTIDAD FEDERATIVA ORIGEN  ORGANO  \
# 0                                21                                21    1005
# 2                                 6                                14    1005
# 3                                14                                14    1005
# 4                                14                                14    1005
# 6                                14                                16    1005
#
#    TIPO TRASPLANTE
# 0                0
# 2                0
# 3                0
# ...

# %%
print(dataset.keys())
# Out:
# Index(['SEXO', 'EDAD AL TRANSPLANTE', 'CODIGO ENTIDAD FEDERATIVA TRASPLANTE',
#        'CODIGO ENTIDAD FEDERATIVA ORGANO', 'CODIGO ENTIDAD FEDERATIVA ORIGEN',
#        'ORGANO', 'TIPO TRASPLANTE'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#               SEXO  EDAD AL TRANSPLANTE  CODIGO ENTIDAD FEDERATIVA TRASPLANTE  \
# count  1732.000000          1732.000000                           1732.000000
# mean      1.443418            45.268476                             13.509815
# std       0.496932            19.238269                              6.931322
# min       1.000000             1.000000                              1.000000
# 25%       1.000000            30.000000                              9.000000
# 50%       1.000000            42.000000                             11.000000
# 75%       2.000000            61.000000                             19.000000
# max       2.000000            90.000000                             32.000000
#
#        CODIGO ENTIDAD FEDERATIVA ORGANO  CODIGO ENTIDAD FEDERATIVA ORIGEN  \
# count                       1732.000000                       1732.000000
# mean                          26.150693                         15.976905
# ...

# %%
X = dataset.drop(labels='SEXO', axis= 1)
Y = dataset['SEXO']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state= 40)

# %%
scaler = StandardScaler().fit(X_test)
print(X_train)
# Out:
#       EDAD AL TRANSPLANTE  CODIGO ENTIDAD FEDERATIVA TRASPLANTE  \
# 1116                   32                                    30
# 771                    70                                     1
# 1630                   73                                    14
# 1437                   33                                    21
# 978                    80                                    21
# ...                   ...                                   ...
# 1016                   55                                    14
# 165                    43                                    15
# 7                      34                                    14
# 219                    73                                     9
# 1350                   50                                    14
#
#       CODIGO ENTIDAD FEDERATIVA ORGANO  CODIGO ENTIDAD FEDERATIVA ORIGEN  \
# 1116                                30                                30
# ...

# %%
# Preprocesamiento: estandarizar las características
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

logistic_regression = LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000)

# %%
logistic_regression.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logistic_regression.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Evaluar el rendimiento del modelo

accuracy = accuracy_score(y_test, y_pred)

print("PUNTUACIÓN Y PRESICIÓN")
print(accuracy_score(y_test, y_pred))
print("")
print("MATRIZ DE CONFUSIÓN")
confusion = confusion_matrix(y_test, y_pred)
print("")
print(confusion_matrix(y_test, y_pred))
print("REPORTE DE CLASIFICACIÓN")
print(classification_report(y_test, y_pred))
# Out:
# PUNTUACIÓN Y PRESICIÓN
# 0.548951048951049
#
# MATRIZ DE CONFUSIÓN
#
# [[216 111]
#  [147  98]]
# REPORTE DE CLASIFICACIÓN
#               precision    recall  f1-score   support
#
#            1       0.60      0.66      0.63       327
#            2       0.47      0.40      0.43       245
#
#     accuracy                           0.55       572
#    macro avg       0.53      0.53      0.53       572
# weighted avg       0.54      0.55      0.54       572
